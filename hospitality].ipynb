# %%
import pandas as pd

# %%
bookings=pd.read_csv(r"C:\Users\Praveen\Desktop\Codebasics\pyhton\source-code\3_project_hospitality_analysis\datasets\fact_bookings.csv")
bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
bookings.head(10)  # to fetch top 10 rows
# Out:
#           booking_id  property_id booking_date check_in_date checkout_date  \
# 0   May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1   May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2   May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3   May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4   May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5   May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6   May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7   May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
# 8   May012216558RT19        16558     30-04-22      1/5/2022      2/5/2022
# 9  May012216558RT110        16558     28-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# ...

# %%
bookings.tail(10)  # to fetch bottom 10 rows
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 134580   Jul312217564RT41        17564     31-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
# 134582   Jul312217564RT43        17564     31-07-22      31-07-22
# 134583   Jul312217564RT44        17564     31-07-22      31-07-22
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 134580      2/8/2022        1.0           RT4    direct online            NaN
# 134581      1/8/2022        4.0           RT4     makeyourtrip            4.0
# ...

# %%
bookings.shape    # how many rows and columns
# Out:
# (134590, 12)

# %%
bookings.describe()  #  give the statistics of the table
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
bookings.columns
# Out:
# Index(['booking_id', 'property_id', 'booking_date', 'check_in_date',
#        'checkout_date', 'no_guests', 'room_category', 'booking_platform',
#        'ratings_given', 'booking_status', 'revenue_generated',
#        'revenue_realized'],
#       dtype='object')

# %%
bookings.info()  # which column contain which datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134587 non-null  float64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      56683 non-null   float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 12.3+ MB

# %%
bookings.booking_platform.unique()   # what are the different bookings types
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
date=pd.read_csv(r"C:\Users\Praveen\Desktop\Codebasics\pyhton\source-code\3_project_hospitality_analysis\datasets\dim_date.csv")
hotels=pd.read_csv(r"C:\Users\Praveen\Desktop\Codebasics\pyhton\source-code\3_project_hospitality_analysis\datasets\dim_hotels.csv")
rooms=pd.read_csv(r"C:\Users\Praveen\Desktop\Codebasics\pyhton\source-code\3_project_hospitality_analysis\datasets\dim_rooms.csv")
aggre_bookings=pd.read_csv(r"C:\Users\Praveen\Desktop\Codebasics\pyhton\source-code\3_project_hospitality_analysis\datasets\fact_aggregated_bookings.csv")
date
hotels
rooms
aggre_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9200 rows x 5 columns]

# %% [markdown]
# Data cleaning

# %%
bookings.describe()   # -ve values in the no_guests
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
bookings[bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings=bookings[bookings.no_guests>0]  #we removed the -ve values  from the table
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134578, 12)

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max() # in this max value is incorrect because  no one charge that huge amount
# Out:
# (6500, 28560000)

# %%
avg,std=df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()
avg,std
# Out:
# (15378.036937686695, 93040.15493143328)

# %%
highest_amount=avg+std*3    #  if he charge max to max this highest  amount
highest_amount
# Out:
# 294498.50173198653

# %%
lowest_amount=avg-std*3    #  if he charge max to max this lowest  amount
lowest_amount
# Out:
# -263742.4278566132

# %%
df_bookings[df_bookings.revenue_generated>highest_amount]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings1=df_bookings[df_bookings.revenue_generated<highest_amount]
df_bookings1
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings1.shape    # before it is 134590 now 134573 because we are removed the  greater than  highest_amount
# Out:
# (134573, 12)

# %%
higher_limit=df_bookings1.revenue_realized.mean()+3*df_bookings1.revenue_realized.std()
higher_limit
# Out:
# 33479.3586618449

# %%
df_bookings1[df_bookings1.revenue_realized>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
df_bookings1[df_bookings1.room_category=='RT4'].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
23439+3*9048
# Out:
# 50583

# %%
rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %% [markdown]
# checking for null values

# %%
df_bookings1.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# Data Transformation

# %%
aggre_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9200 rows x 5 columns]

# %%
aggre_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
aggre_bookings['occupancy %']=(aggre_bookings.successful_bookings/aggre_bookings.capacity)*100

# %%
aggre_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occupancy %
# 0       83.333333
# ...

# %% [markdown]
# what is the average occupancy rate in each of the room category

# %%
aggre_bookings.groupby('room_category')['occupancy %'].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occupancy %, dtype: float64

# %%
merge=pd.merge(aggre_bookings,rooms,right_on="room_id",left_on="room_category")
merge
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occupancy % room_id    room_class
# ...

# %%
merge.tail()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occupancy %    room_class
# 9195    72.222222  Presidential
# 9196    72.222222  Presidential
# 9197    50.000000  Presidential
# 9198    50.000000  Presidential
# 9199    75.000000  Presidential

# %%
merge
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occupancy %    room_class
# ...

# %% [markdown]
# print average occupancy rate per city

# %%
hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
df=pd.merge(merge,hotels,on='property_id')
df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           16559      2-May-22           RT1                   20      30.0
# 2           16559      3-May-22           RT1                   17      30.0
# 3           16559      4-May-22           RT1                   21      30.0
# 4           16559      5-May-22           RT1                   16      30.0
# ...           ...           ...           ...                  ...       ...
# 9195        18560     27-Jul-22           RT4                    6      15.0
# 9196        18560     28-Jul-22           RT4                    9      15.0
# 9197        18560     29-Jul-22           RT4                    8      15.0
# 9198        18560     30-Jul-22           RT4                    9      15.0
# 9199        18560     31-Jul-22           RT4                   12      15.0
#
# ...

# %%
df.groupby('city')['occupancy %'].mean().round(2).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='city'>

# %% [markdown]
# when  was the occupancy better? weekend or weekday

# %%
date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df1=pd.merge(df,date,left_on='check_in_date',right_on='date')
df1
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559     10-May-22           RT1                   18      30.0
# 1           16559     10-May-22           RT2                   25      41.0
# 2           16559     10-May-22           RT3                   20      32.0
# 3           16559     10-May-22           RT4                   13      18.0
# 4           19562     10-May-22           RT1                   18      30.0
# ...           ...           ...           ...                  ...       ...
# 6495        17564     31-Jul-22           RT4                   10      17.0
# 6496        18560     31-Jul-22           RT1                   22      30.0
# 6497        18560     31-Jul-22           RT2                   34      40.0
# 6498        18560     31-Jul-22           RT3                   17      24.0
# 6499        18560     31-Jul-22           RT4                   12      15.0
#
# ...

# %%
df1.groupby('day_type')['occupancy %'].mean().round(2).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='day_type'>

# %% [markdown]
# In the month of june,what is the occupancy for different cities

# %%
df1['mmm yy'].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june_22=df1[df1["mmm yy"]=='Jun 22']
df_june_22
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        16559     10-Jun-22           RT2                   26      41.0
# 2202        16559     10-Jun-22           RT3                   20      32.0
# 2203        16559     10-Jun-22           RT4                   11      18.0
# 2204        19562     10-Jun-22           RT1                   19      30.0
# ...           ...           ...           ...                  ...       ...
# 4295        17564     30-Jun-22           RT4                    7      17.0
# 4296        18560     30-Jun-22           RT1                   18      30.0
# 4297        18560     30-Jun-22           RT2                   24      40.0
# 4298        18560     30-Jun-22           RT3                   14      24.0
# 4299        18560     30-Jun-22           RT4                    8      15.0
#
# ...

# %%
df_june_22.groupby('city')['occupancy %'].mean().round()
# Out:
# city
# Bangalore    57.0
# Delhi        62.0
# Hyderabad    58.0
# Mumbai       58.0
# Name: occupancy %, dtype: float64

# %%
august=pd.read_csv(r"C:\Users\Praveen\Desktop\Codebasics\pyhton\source-code\3_project_hospitality_analysis\datasets\new_data_august.csv")
august
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
# 5        17561      Atliq Blu    Luxury     Mumbai           RT1   Standard
# 6        17564  Atliq Seasons  Business     Mumbai           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# ...

# %%
df1.shape
# Out:
# (6500, 14)

# %%
august.shape
# Out:
# (7, 13)

# %%
new_df=pd.concat([df1,august],ignore_index=True,axis=0)    # axis=0 here it will add in row wise if do u want in column axis=1
new_df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559     10-May-22           RT1                   18      30.0
# 1           16559     10-May-22           RT2                   25      41.0
# 2           16559     10-May-22           RT3                   20      32.0
# 3           16559     10-May-22           RT4                   13      18.0
# 4           19562     10-May-22           RT1                   18      30.0
# ...           ...           ...           ...                  ...       ...
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
# ...

# %%
new_df.shape #   from august and df1 6500+7
# Out:
# (6507, 15)

# %% [markdown]
# print revenue_realized per city

# %%
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
new_df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559     10-May-22           RT1                   18      30.0
# 1           16559     10-May-22           RT2                   25      41.0
# 2           16559     10-May-22           RT3                   20      32.0
# 3           16559     10-May-22           RT4                   13      18.0
# 4           19562     10-May-22           RT1                   18      30.0
# ...           ...           ...           ...                  ...       ...
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
# ...

# %%
hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df3=pd.merge(df_bookings,hotels,on='property_id')
df3
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558     30-04-22      1/5/2022
# 1        May012216558RT13        16558     28-04-22      1/5/2022
# 2        May012216558RT15        16558     27-04-22      1/5/2022
# 3        May012216558RT16        16558     1/5/2022      1/5/2022
# 4        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134573   Jul312217564RT45        17564     30-07-22      31-07-22
# 134574   Jul312217564RT46        17564     29-07-22      31-07-22
# 134575   Jul312217564RT48        17564     30-07-22      31-07-22
# 134576   Jul312217564RT49        17564     29-07-22      31-07-22
# 134577  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
import matplotlib.pyplot as plt

(df3.groupby('city')['revenue_realized'].sum()/1000000).plot(kind="bar")      #revenue_realized is in millions
plt.title("revenue_realized per city")
# Out:
# Text(0.5, 1.0, 'revenue_realized per city')

# %% [markdown]
# print month by month revenue

# %%
date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df3
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558     30-04-22      1/5/2022
# 1        May012216558RT13        16558     28-04-22      1/5/2022
# 2        May012216558RT15        16558     27-04-22      1/5/2022
# 3        May012216558RT16        16558     1/5/2022      1/5/2022
# 4        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134573   Jul312217564RT45        17564     30-07-22      31-07-22
# 134574   Jul312217564RT46        17564     29-07-22      31-07-22
# 134575   Jul312217564RT48        17564     30-07-22      31-07-22
# 134576   Jul312217564RT49        17564     29-07-22      31-07-22
# 134577  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134578 entries, 0 to 134577
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134578 non-null  object
#  1   property_id        134578 non-null  int64
#  2   booking_date       134578 non-null  object
#  3   check_in_date      134578 non-null  object
#  4   checkout_date      134578 non-null  object
#  5   no_guests          134578 non-null  float64
#  6   room_category      134578 non-null  object
#  7   booking_platform   134578 non-null  object
#  8   ratings_given      56679 non-null   float64
#  9   booking_status     134578 non-null  object
#  10  revenue_generated  134578 non-null  int64
#  11  revenue_realized   134578 non-null  int64
#  12  property_name      134578 non-null  object
#  13  category           134578 non-null  object
#  14  city               134578 non-null  object
# ...

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
date['date']=pd.to_datetime(date['date'])
date
# Out:
#          date  mmm yy week no  day_type
# 0  2022-05-01  May 22    W 19   weekend
# 1  2022-05-02  May 22    W 19  weekeday
# 2  2022-05-03  May 22    W 19  weekeday
# 3  2022-05-04  May 22    W 19  weekeday
# 4  2022-05-05  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87 2022-07-27  Jul 22    W 31  weekeday
# 88 2022-07-28  Jul 22    W 31  weekeday
# 89 2022-07-29  Jul 22    W 31  weekeday
# 90 2022-07-30  Jul 22    W 31   weekend
# 91 2022-07-31  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB

# %%
df3['check_in_date']=pd.to_datetime(df3['check_in_date'])
df3
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558     30-04-22    2022-01-05
# 1        May012216558RT13        16558     28-04-22    2022-01-05
# 2        May012216558RT15        16558     27-04-22    2022-01-05
# 3        May012216558RT16        16558     1/5/2022    2022-01-05
# 4        May012216558RT17        16558     28-04-22    2022-01-05
# ...                   ...          ...          ...           ...
# 134573   Jul312217564RT45        17564     30-07-22    2022-07-31
# 134574   Jul312217564RT46        17564     29-07-22    2022-07-31
# 134575   Jul312217564RT48        17564     30-07-22    2022-07-31
# 134576   Jul312217564RT49        17564     29-07-22    2022-07-31
# 134577  Jul312217564RT410        17564     31-07-22    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134578 entries, 0 to 134577
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134578 non-null  object
#  1   property_id        134578 non-null  int64
#  2   booking_date       134578 non-null  object
#  3   check_in_date      134578 non-null  datetime64[ns]
#  4   checkout_date      134578 non-null  object
#  5   no_guests          134578 non-null  float64
#  6   room_category      134578 non-null  object
#  7   booking_platform   134578 non-null  object
#  8   ratings_given      56679 non-null   float64
#  9   booking_status     134578 non-null  object
#  10  revenue_generated  134578 non-null  int64
#  11  revenue_realized   134578 non-null  int64
#  12  property_name      134578 non-null  object
#  13  category           134578 non-null  object
#  14  city               134578 non-null  object
# ...

# %%
df4=pd.merge(df3,date,left_on="check_in_date",right_on="date")
df4
# Out:
#               booking_id  property_id booking_date check_in_date  \
# 0       May052216558RT11        16558     15-04-22    2022-05-05
# 1       May052216558RT12        16558     30-04-22    2022-05-05
# 2       May052216558RT13        16558     1/5/2022    2022-05-05
# 3       May052216558RT14        16558     3/5/2022    2022-05-05
# 4       May052216558RT15        16558     30-04-22    2022-05-05
# ...                  ...          ...          ...           ...
# 92574   Jul312217564RT45        17564     30-07-22    2022-07-31
# 92575   Jul312217564RT46        17564     29-07-22    2022-07-31
# 92576   Jul312217564RT48        17564     30-07-22    2022-07-31
# 92577   Jul312217564RT49        17564     29-07-22    2022-07-31
# 92578  Jul312217564RT410        17564     31-07-22    2022-07-31
#
#       checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0          7/5/2022        3.0           RT1         tripster            5.0
# ...

# %%
df4.groupby('mmm yy')['revenue_realized'].sum().plot(kind='bar')
plt.title("revenue month by month")
plt.grid()

# %%
df3
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558     30-04-22    2022-01-05
# 1        May012216558RT13        16558     28-04-22    2022-01-05
# 2        May012216558RT15        16558     27-04-22    2022-01-05
# 3        May012216558RT16        16558     1/5/2022    2022-01-05
# 4        May012216558RT17        16558     28-04-22    2022-01-05
# ...                   ...          ...          ...           ...
# 134573   Jul312217564RT45        17564     30-07-22    2022-07-31
# 134574   Jul312217564RT46        17564     29-07-22    2022-07-31
# 134575   Jul312217564RT48        17564     30-07-22    2022-07-31
# 134576   Jul312217564RT49        17564     29-07-22    2022-07-31
# 134577  Jul312217564RT410        17564     31-07-22    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
df5=pd.merge(hotels,df3,on='property_id')
df5
# Out:
#         property_id property_name_x category_x  city_x         booking_id  \
# 0             16558    Atliq Grands     Luxury   Delhi   May012216558RT12
# 1             16558    Atliq Grands     Luxury   Delhi   May012216558RT13
# 2             16558    Atliq Grands     Luxury   Delhi   May012216558RT15
# 3             16558    Atliq Grands     Luxury   Delhi   May012216558RT16
# 4             16558    Atliq Grands     Luxury   Delhi   May012216558RT17
# ...             ...             ...        ...     ...                ...
# 134573        17564   Atliq Seasons   Business  Mumbai   Jul312217564RT45
# 134574        17564   Atliq Seasons   Business  Mumbai   Jul312217564RT46
# 134575        17564   Atliq Seasons   Business  Mumbai   Jul312217564RT48
# 134576        17564   Atliq Seasons   Business  Mumbai   Jul312217564RT49
# 134577        17564   Atliq Seasons   Business  Mumbai  Jul312217564RT410
#
#        booking_date check_in_date checkout_date  no_guests room_category  \
# ...

# %% [markdown]
# print revenue realized per hotel type

# %%
df5.groupby('category_x')['revenue_realized'].sum()
# Out:
# category_x
# Business     655967037
# Luxury      1052636842
# Name: revenue_realized, dtype: int64

# %% [markdown]
# print a pie chart of revenue realized  per booking platform

# %%
df5.groupby('booking_platform')['revenue_realized'].sum().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='revenue_realized'>

# %% [markdown]
# print average rating per city

# %%
df5.groupby('city_x')['ratings_given'].mean().round(2)
# Out:
# city_x
# Bangalore    3.41
# Delhi        3.78
# Hyderabad    3.66
# Mumbai       3.65
# Name: ratings_given, dtype: float64

# %%
hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
date
# Out:
#          date  mmm yy week no  day_type
# 0  2022-05-01  May 22    W 19   weekend
# 1  2022-05-02  May 22    W 19  weekeday
# 2  2022-05-03  May 22    W 19  weekeday
# 3  2022-05-04  May 22    W 19  weekeday
# 4  2022-05-05  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87 2022-07-27  Jul 22    W 31  weekeday
# 88 2022-07-28  Jul 22    W 31  weekeday
# 89 2022-07-29  Jul 22    W 31  weekeday
# 90 2022-07-30  Jul 22    W 31   weekend
# 91 2022-07-31  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
aggre_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occupancy %
# 0       83.333333
# ...
